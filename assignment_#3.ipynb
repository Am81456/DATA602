# %% [markdown]
# ***ASSIGNMENT ON CHOCOLATE***
#
#
# In this project, the data I used is from Kagele 'chocolate' file. that includes the company,
# the rating, ingredients and the location with the review dates. and it will be cleaned and sorted
# and put in graph in this assignment.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import os
import matplotlib.pyplot as plt 

# %matplotlib inline


data1 = pd.read_csv('chocolate.csv')
data1.head()
# Out:
#    Unnamed: 0   ref   company company_location  review_date  \
# 0           0  2454      5150            U.S.A         2019
# 1           1  2458      5150            U.S.A         2019
# 2           2  2454      5150            U.S.A         2019
# 3           3   797  A. Morin           France         2012
# 4           4   797  A. Morin           France         2012
#
#   country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0             Madagascar           Bejofo Estate, batch 1           76.0
# 1     Dominican republic                  Zorzal, batch 1           76.0
# 2               Tanzania            Kokoa Kamili, batch 1           76.0
# 3                   Peru                             Peru           63.0
# 4                Bolivia                          Bolivia           70.0
#
#    rating  counts_of_ingredients  ...       cocoa_butter          vanilla  \
# 0    3.75                      3  ...  have_cocoa_butter  have_not_vanila
# ...

# %%
data1.shape
# Out:
# (2224, 21)

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'ref', 'company', 'company_location', 'review_date',
#        'country_of_bean_origin', 'specific_bean_origin_or_bar_name',
#        'cocoa_percent', 'rating', 'counts_of_ingredients', 'beans',
#        'cocoa_butter', 'vanilla', 'lecithin', 'salt', 'sugar',
#        'sweetener_without_sugar', 'first_taste', 'second_taste', 'third_taste',
#        'fourth_taste'],
#       dtype='object')

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=2224, step=1)

# %%
data1.values
# Out:
# array([[0, 2454, '5150', ..., 'blackberry', 'full body', nan],
#        [1, 2458, '5150', ..., 'vegetal', 'savory', nan],
#        [2, 2454, '5150', ..., 'fatty', 'bready', nan],
#        ...,
#        [2221, 2170, 'Zotter', ..., 'roasty', 'accessible', nan],
#        [2222, 2170, 'Zotter', ..., 'mild nuts', 'mild fruit', nan],
#        [2223, 2036, 'Zotter', ..., 'earthy', 'cocoa', nan]], dtype=object)

# %% [markdown]
# **Using the dropna function to remove Nan values in the data Frame**

# %%
data1.dropna(how='all')
# Out:
#       Unnamed: 0   ref   company company_location  review_date  \
# 0              0  2454      5150            U.S.A         2019
# 1              1  2458      5150            U.S.A         2019
# 2              2  2454      5150            U.S.A         2019
# 3              3   797  A. Morin           France         2012
# 4              4   797  A. Morin           France         2012
# ...          ...   ...       ...              ...          ...
# 2219        2219  1205    Zotter          Austria         2014
# 2220        2220  1996    Zotter          Austria         2017
# 2221        2221  2170    Zotter          Austria         2018
# 2222        2222  2170    Zotter          Austria         2018
# 2223        2223  2036    Zotter          Austria         2018
#
#      country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0                Madagascar           Bejofo Estate, batch 1           76.0
# ...

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.shape
# Out:
# (2224, 21)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        2224 non-null   int64
#  1   ref                               2224 non-null   int64
#  2   company                           2224 non-null   object
#  3   company_location                  2224 non-null   object
#  4   review_date                       2224 non-null   int64
#  5   country_of_bean_origin            2224 non-null   object
#  6   specific_bean_origin_or_bar_name  2224 non-null   object
#  7   cocoa_percent                     2224 non-null   float64
#  8   rating                            2224 non-null   float64
#  9   counts_of_ingredients             2224 non-null   int64
#  10  beans                             2224 non-null   object
# ...

# %%
data1.isnull().sum()
# Out:
# Unnamed: 0                             0
# ref                                    0
# company                                0
# company_location                       0
# review_date                            0
# country_of_bean_origin                 0
# specific_bean_origin_or_bar_name       0
# cocoa_percent                          0
# rating                                 0
# counts_of_ingredients                  0
# beans                                  0
# cocoa_butter                           0
# vanilla                                0
# lecithin                               0
# salt                                   0
# sugar                                  0
# sweetener_without_sugar                0
# first_taste                            0
# second_taste                          77
# third_taste                          620
# fourth_taste                        1982
# dtype: int64

# %% [markdown]
# **Used the drop function to remove the  null functions and functions that doesnt have a correlation in the data frame**

# %%
data1 = data1.drop(data1.columns[[0, 1, 4, 17, 18, 19, 20]], axis=1)

# %%
data1
# Out:
#        company company_location country_of_bean_origin  \
# 0         5150            U.S.A             Madagascar
# 1         5150            U.S.A     Dominican republic
# 2         5150            U.S.A               Tanzania
# 3     A. Morin           France                   Peru
# 4     A. Morin           France                Bolivia
# ...        ...              ...                    ...
# 2219    Zotter          Austria                  Blend
# 2220    Zotter          Austria               Colombia
# 2221    Zotter          Austria                 Belize
# 2222    Zotter          Austria                  Congo
# 2223    Zotter          Austria                  Blend
#
#      specific_bean_origin_or_bar_name  cocoa_percent  rating  \
# 0              Bejofo Estate, batch 1           76.0    3.75
# 1                     Zorzal, batch 1           76.0    3.50
# 2               Kokoa Kamili, batch 1           76.0    3.25
# ...

# %%
data1.dtypes
# Out:
# company                              object
# company_location                     object
# country_of_bean_origin               object
# specific_bean_origin_or_bar_name     object
# cocoa_percent                       float64
# rating                              float64
# counts_of_ingredients                 int64
# beans                                object
# cocoa_butter                         object
# vanilla                              object
# lecithin                             object
# salt                                 object
# sugar                                object
# sweetener_without_sugar              object
# dtype: object

# %% [markdown]
# **This shows the correlation of the data**

# %%
import seaborn as sns

sns.heatmap(data1.corr())
# Out:
# <AxesSubplot:>

# %%
(data1
 .select_dtypes(int)
 .describe()
)
# Out:
#        counts_of_ingredients
# count            2224.000000
# mean                3.075989
# std                 0.929875
# min                 1.000000
# 25%                 2.000000
# 50%                 3.000000
# 75%                 4.000000
# max                 6.000000

# %%
#data1.drop(['company_location','counts_of_ingredients'], axis = 1, inplace=True)

# %%
data1.values
# Out:
# array([['5150', 'U.S.A', 'Madagascar', ..., 'have_not_salt',
#         'have_sugar', 'have_not_sweetener_without_sugar'],
#        ['5150', 'U.S.A', 'Dominican republic', ..., 'have_not_salt',
#         'have_sugar', 'have_not_sweetener_without_sugar'],
#        ['5150', 'U.S.A', 'Tanzania', ..., 'have_not_salt', 'have_sugar',
#         'have_not_sweetener_without_sugar'],
#        ...,
#        ['Zotter', 'Austria', 'Belize', ..., 'have_not_salt',
#         'have_sugar', 'have_not_sweetener_without_sugar'],
#        ['Zotter', 'Austria', 'Congo', ..., 'have_not_salt', 'have_sugar',
#         'have_not_sweetener_without_sugar'],
#        ['Zotter', 'Austria', 'Blend', ..., 'have_not_salt', 'have_sugar',
#         'have_not_sweetener_without_sugar']], dtype=object)

# %%
data1
# Out:
#        company company_location country_of_bean_origin  \
# 0         5150            U.S.A             Madagascar
# 1         5150            U.S.A     Dominican republic
# 2         5150            U.S.A               Tanzania
# 3     A. Morin           France                   Peru
# 4     A. Morin           France                Bolivia
# ...        ...              ...                    ...
# 2219    Zotter          Austria                  Blend
# 2220    Zotter          Austria               Colombia
# 2221    Zotter          Austria                 Belize
# 2222    Zotter          Austria                  Congo
# 2223    Zotter          Austria                  Blend
#
#      specific_bean_origin_or_bar_name  cocoa_percent  rating  \
# 0              Bejofo Estate, batch 1           76.0    3.75
# 1                     Zorzal, batch 1           76.0    3.50
# 2               Kokoa Kamili, batch 1           76.0    3.25
# ...

# %% [markdown]
# **use the null function to see if there is a missing function in the data frame and as we see the result there is no missing data and the data is clean**

# %%
data1.isnull().sum()
# Out:
# company                             0
# company_location                    0
# country_of_bean_origin              0
# specific_bean_origin_or_bar_name    0
# cocoa_percent                       0
# rating                              0
# counts_of_ingredients               0
# beans                               0
# cocoa_butter                        0
# vanilla                             0
# lecithin                            0
# salt                                0
# sugar                               0
# sweetener_without_sugar             0
# dtype: int64

# %%
data1.shape
# Out:
# (2224, 14)

# %%
(data1
 .select_dtypes('float')
 .describe()
)
# Out:
#        cocoa_percent       rating
# count    2224.000000  2224.000000
# mean       71.493930     3.198561
# std         5.278253     0.434329
# min        42.000000     1.000000
# 25%        70.000000     3.000000
# 50%        70.000000     3.250000
# 75%        74.000000     3.500000
# max       100.000000     4.000000

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
data1.describe()
# Out:
#        cocoa_percent       rating  counts_of_ingredients
# count    2224.000000  2224.000000            2224.000000
# mean       71.493930     3.198561               3.075989
# std         5.278253     0.434329               0.929875
# min        42.000000     1.000000               1.000000
# 25%        70.000000     3.000000               2.000000
# 50%        70.000000     3.250000               3.000000
# 75%        74.000000     3.500000               4.000000
# max       100.000000     4.000000               6.000000

# %%
print (data1['company'].sort_values().unique())
# Out:
# ['5150' 'A. Morin' 'AMMA' 'Acalli' 'Adi aka Fijiana (Easy In Ltd)' 'Aelan'
#  'Aequare (Gianduja)' 'Ah Cacao' "Akesson's (Pralus)" 'Alain Ducasse'
#  'Alexandre' 'Altus aka Cao Artisan' 'Amano' 'Amatller (Simon Coll)'
#  'Amazona' 'Ambrosia' 'Amedei' 'Anahata' 'Animas' 'Ara' 'Arete'
#  'Argencove' 'Artisan du Chocolat' 'Artisan du Chocolat (Casa Luker)'
#  'Askinosie' 'Atypic' 'Auro' 'Bahen & Co.' 'Baiani' 'Bakau' 'Bankston'
#  'Bar Au Chocolat' "Baravelli's" 'Batch' 'Bean' 'Beau Cacao' 'Beehive'
#  'Belcolade' 'Bellflower' 'Belvie' 'Belyzium' 'Benns' 'Benoit Nihant'
#  'Bernachon' 'Beschle (Felchlin)' 'Bisou' 'Bitacora' 'Bittersweet Origins'
#  'Bixby' 'Black Mountain' 'Black River (A. Morin)' 'Blanxart'
#  'Blue Bandana' 'Boho' 'Bonaterra' 'Bonnat' 'Bouga Cacao (Tulicorp)'
#  'Box Chocolate' 'Brasstown' "Brasstown aka It's Chocolate" 'Brazen'
#  'Breeze Mill' 'Bright' 'Britarev' 'Bronx Grrl Chocolate' 'Bullion'
#  'Burnt Fork Bend' 'By Cacao' 'C-Amaro' 'Cacai Cacao' 'Cacao 70'
# ...

# %%
data1['rating'].describe()
# Out:
# count    2224.000000
# mean        3.198561
# std         0.434329
# min         1.000000
# 25%         3.000000
# 50%         3.250000
# 75%         3.500000
# max         4.000000
# Name: rating, dtype: float64

# %%
data1['cocoa_percent'].describe()
# Out:
# count    2224.000000
# mean       71.493930
# std         5.278253
# min        42.000000
# 25%        70.000000
# 50%        70.000000
# 75%        74.000000
# max       100.000000
# Name: cocoa_percent, dtype: float64

# %%
plt.figure(figsize=(10,7))
plt.hist(data1['rating'])
plt.xlabel('rating')
plt.ylabel('cocoa_percent')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,7))
plt.hist(data1['cocoa_percent'])
plt.xlabel('cocoa_percent')
plt.ylabel('rating')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(f'Row: {data1.shape[0]:,}')

print(f'Columns: {data1.shape[1]:,}')
# Out:
# Row: 2,224
# Columns: 14

# %%
data1.columns
# Out:
# Index(['company', 'company_location', 'country_of_bean_origin',
#        'specific_bean_origin_or_bar_name', 'cocoa_percent', 'rating',
#        'counts_of_ingredients', 'beans', 'cocoa_butter', 'vanilla', 'lecithin',
#        'salt', 'sugar', 'sweetener_without_sugar'],
#       dtype='object')

# %%
data1 = data1.dropna()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2224 entries, 0 to 2223
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   company                           2224 non-null   object
#  1   company_location                  2224 non-null   object
#  2   country_of_bean_origin            2224 non-null   object
#  3   specific_bean_origin_or_bar_name  2224 non-null   object
#  4   cocoa_percent                     2224 non-null   float64
#  5   rating                            2224 non-null   float64
#  6   counts_of_ingredients             2224 non-null   int64
#  7   beans                             2224 non-null   object
#  8   cocoa_butter                      2224 non-null   object
#  9   vanilla                           2224 non-null   object
#  10  lecithin                          2224 non-null   object
# ...

# %% [markdown]
# ***Now the data is sorted in the rating of the chocolate***

# %%
data1_sorted = data1.sort_values(by = 'rating', ascending = False).head()
data1_sorted
# Out:
#                 company company_location country_of_bean_origin  \
# 1071  Idilio (Felchlin)      Switzerland              Venezuela
# 2104           Valrhona           France             Madagascar
# 218       Benoit Nihant          Belgium              Indonesia
# 112               Arete            U.S.A              Nicaragua
# 220       Benoit Nihant          Belgium                Ecuador
#
#                    specific_bean_origin_or_bar_name  cocoa_percent  rating  \
# 1071  Sur del Lago, Amiari Meridena, Zulia, w/ nibs           72.0     4.0
# 2104                                        Manjari           64.0     4.0
# 218        Bali, Sukrama Bros. Farm, Melaya, 62hr C           72.0     4.0
# 112                                           Chuno           70.0     4.0
# 220                                   Rio Peripa H.           73.0     4.0
#
#       counts_of_ingredients      beans           cocoa_butter  \
# 1071                      3  have_bean      have_cocoa_butter
# ...

# %%
import seaborn as sns

sns.heatmap(data1.corr())
# Out:
# <AxesSubplot:>

# %%
data1_sorted = data1.sort_values(by = 'counts_of_ingredients', ascending = False).head()
data1_sorted
# Out:
#                company    company_location country_of_bean_origin  \
# 51       Alain Ducasse              France                 Mexico
# 49       Alain Ducasse              France               Trinidad
# 797   Forteza (Cortes)         Puerto rico     Dominican republic
# 798   Forteza (Cortes)         Puerto rico     Dominican republic
# 1112           Kah Kow  Dominican republic     Dominican republic
#
#      specific_bean_origin_or_bar_name  cocoa_percent  rating  \
# 51                 Porcelana, Mexique           75.0    3.50
# 49                            Trinite           65.0    2.75
# 797                Dominican Republic           70.0    2.75
# 798                       Puerto Rico           80.0    2.75
# 1112         Rizek Cacao, Domin. Rep.           62.0    3.25
#
#       counts_of_ingredients      beans       cocoa_butter      vanilla  \
# 51                        6  have_bean  have_cocoa_butter  have_vanila
# ...

# %%
data1.columns = data1.columns.str.replace(' ','')

# %% [markdown]
# **this shows that there is no missing values in the data.**

# %%
data1.isnull().sum()
# Out:
# company                             0
# company_location                    0
# country_of_bean_origin              0
# specific_bean_origin_or_bar_name    0
# cocoa_percent                       0
# rating                              0
# counts_of_ingredients               0
# beans                               0
# cocoa_butter                        0
# vanilla                             0
# lecithin                            0
# salt                                0
# sugar                               0
# sweetener_without_sugar             0
# dtype: int64

# %%
fig = plt.figure(figsize = (20,10))
sns.barplot(x = 'company', y = 'rating', data=data1)
# Out:
# <AxesSubplot:xlabel='company', ylabel='rating'>

# %% [markdown]
# ***this graph shows the correlation of the cocoa percentage with the company location***

# %%
fig = plt.figure(figsize = (50,25))
sns.barplot(x = 'cocoa_percent' , y = 'company_location', data = data1)
plt.title('correlation between company location and cocoa percentage', fontweight='bold', fontsize=27)
plt.xlabel('cocoa_percent', fontweight='bold', fontsize=27)
plt.ylabel('company_location', fontweight='bold', fontsize=27)
# Out:
# Text(0, 0.5, 'company_location')

# %%
print (data1['country_of_bean_origin'].sort_values().unique())
# Out:
# ['Australia' 'Belize' 'Blend' 'Bolivia' 'Bolvia' 'Brazil' 'Burma'
#  'Cameroon' 'Colombia' 'Congo' 'Costa rica' 'Cuba' 'Dominican republic'
#  'Dr congo' 'Ecuador' 'El salvador' 'Fiji' 'Gabon' 'Ghana' 'Grenada'
#  'Guatemala' 'Haiti' 'Honduras' 'India' 'Indonesia' 'Ivory coast'
#  'Jamaica' 'Liberia' 'Madagascar' 'Malaysia' 'Martinique' 'Mexico'
#  'Nicaragua' 'Nigeria' 'Panama' 'Papua new guinea' 'Peru' 'Philippines'
#  'Principe' 'Puerto rico' 'Samoa' 'Sao tome' 'Sao tome & principe'
#  'Sierra leone' 'Solomon islands' 'Sri lanka' 'St. lucia'
#  'St.vincent-grenadines' 'Sulawesi' 'Sumatra' 'Suriname' 'Taiwan'
#  'Tanzania' 'Thailand' 'Tobago' 'Togo' 'Trinidad' 'U.s.a.' 'Uganda'
#  'Vanuatu' 'Venezuela' 'Vietnam']

# %%
data1.columns
# Out:
# Index(['company', 'company_location', 'country_of_bean_origin',
#        'specific_bean_origin_or_bar_name', 'cocoa_percent', 'rating',
#        'counts_of_ingredients', 'beans', 'cocoa_butter', 'vanilla', 'lecithin',
#        'salt', 'sugar', 'sweetener_without_sugar'],
#       dtype='object')

# %%
data1.groupby('cocoa_percent').describe().T
# Out:
# cocoa_percent                42.0   46.0   50.0   53.0       55.0      56.0   \
# rating                count   1.00   1.00   1.00    1.0  15.000000  2.000000
#                       mean    2.75   2.75   3.75    2.0   2.900000  3.250000
#                       std      NaN    NaN    NaN    NaN   0.338062  0.000000
#                       min     2.75   2.75   3.75    2.0   2.500000  3.250000
#                       25%     2.75   2.75   3.75    2.0   2.750000  3.250000
#                       50%     2.75   2.75   3.75    2.0   2.750000  3.250000
#                       75%     2.75   2.75   3.75    2.0   3.125000  3.250000
#                       max     2.75   2.75   3.75    2.0   3.500000  3.250000
# counts_of_ingredients count   1.00   1.00   1.00    1.0  15.000000  2.000000
#                       mean    4.00   5.00   4.00    5.0   4.200000  4.500000
#                       std      NaN    NaN    NaN    NaN   0.676123  0.707107
# ...

# %%
plt.rcParams["figure.figsize"] = (10,10)

data1.hist()
plt.show()

# %%
data1 = np.random.rand(10, 12)


ax = sns.heatmap(data1)

# %%
data1 = pd.DataFrame(np.random.rand(10, 4), columns=["rating", "counts_of_ingredients", "company_location", "cocoa_percent"])

data1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure()

data1.diff().hist(color="k", alpha=0.5, bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>,
#         <AxesSubplot:title={'center':'counts_of_ingredients'}>],
#        [<AxesSubplot:title={'center':'company_location'}>,
#         <AxesSubplot:title={'center':'cocoa_percent'}>]], dtype=object)

# %%
data1.groupby('cocoa_percent').sum()
# Out:
#                  rating  counts_of_ingredients  company_location
# cocoa_percent
# 0.013902       0.489785               0.398934          0.975913
# 0.228749       0.156960               0.869778          0.295226
# 0.261713       0.528967               0.700350          0.386760
# 0.345737       0.244375               0.844894          0.992287
# 0.581442       0.664969               0.276292          0.819944
# 0.722274       0.768031               0.018390          0.942270
# 0.889853       0.194334               0.324003          0.221057
# 0.946625       0.325273               0.911798          0.140507
# 0.996389       0.341714               0.359774          0.433826
# 0.999102       0.370758               0.014838          0.272968
